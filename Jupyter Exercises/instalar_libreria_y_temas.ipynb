# %%
# instalamos una librería
# !pip install jupyterthemes
# Out:
# ...
#      ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.0 MB 1.9 MB/s eta 0:00:04
#      - -------------------------------------- 0.2/7.0 MB 2.4 MB/s eta 0:00:03
#      -- ------------------------------------- 0.5/7.0 MB 3.6 MB/s eta 0:00:02
#      --- ------------------------------------ 0.6/7.0 MB 3.9 MB/s eta 0:00:02
#      ----- ---------------------------------- 0.9/7.0 MB 4.0 MB/s eta 0:00:02
#      ------- -------------------------------- 1.2/7.0 MB 4.6 MB/s eta 0:00:02
#      -------- ------------------------------- 1.5/7.0 MB 4.9 MB/s eta 0:00:02
#      ---------- ----------------------------- 1.8/7.0 MB 5.0 MB/s eta 0:00:02
#      ----------- ---------------------------- 2.1/7.0 MB 5.3 MB/s eta 0:00:01
#      ------------ --------------------------- 2.2/7.0 MB 5.1 MB/s eta 0:00:01
#      -------------- ------------------------- 2.6/7.0 MB 5.3 MB/s eta 0:00:01
# ...

# %% [markdown]
# https://github.com/dunovank/jupyter-themes

# %%
pip install --upgrade jupyterthemes
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Se debe reiniciar todo Jupyter 
# !jt -t monokai -N -T -kl
